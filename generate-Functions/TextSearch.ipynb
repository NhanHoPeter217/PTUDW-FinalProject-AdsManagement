# %%
import requests
import json
import re
import random

# %%
# Use regular expression to find the text between "Phường " and the next comma
def getWardFromAddress(address_string):
    match = re.search(r'Phường ([^,]*)(?=,)', address_string)
    match2 = re.search(r'Ward ([^,]*)(?=,)', address_string)
    match3 = re.search(r', (.*), Quận', address_string)

    if match:
        ward_info = match.group(1)
    elif match2:
        ward_info = match2.group(1)
    elif match3:
        ward_info = match3.group(1)
    else:
        ward_info = ''
        print("[Regex] Fail to find ward in ", address_string)
    return ward_info

# Use regular expression to find the text between "Quận " and the next comma
def getDistrictFromAddress(address_string):
    match = re.search(r'Quận ([^,]*)(?=,)', address_string)
    match2 = re.search(r'District ([^,]*)(?=,)', address_string)
    match3 = re.search(r'Phường [^,]*, ([^,]*)', address_string)

    if match:
        district = match.group(1)
    elif match2:
        district = match2.group(1)
    elif match3:
        district = match3.group(1)
    else:
        district = ''
        print("[Regex] Fail to find district in ", address_string)
    return district

# %%
adsFormat = ['Cổ động chính trị', 'Quảng cáo thương mại', 'Xã hội hoá']

typeOfLocation = [
                'Đất công/Công viên/Hành lang an toàn giao thông',
                'Đất tư nhân/Nhà ở riêng lẻ',
                'Trung tâm thương mại',
                'Chợ',
                'Cây xăng',
                'Nhà chờ xe buýt'
]

# %%
def getLocation(address_string):
    url = "https://places.googleapis.com/v1/places:searchText"
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": "AIzaSyAZP9odw7JOw7LqqIJXcfNxZIh4qxpEK6I",
        "X-Goog-FieldMask": "places.displayName,places.formattedAddress,places.location,places.addressComponents"
    }
    data = {
        "textQuery": address_string,
        "locationBias": {
            "circle": {
                "center": {
                    "latitude": 10.774669,
                    "longitude": 106.69247
                },
                "radius": 5000
            }
        },
        "languageCode": "en"
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))
    response_json = json.loads(response.text)

    place = response_json['places'][0]
    print(place)
    output = {
        'title': place['displayName']['text'],        
        'lat': place['location']['latitude'],
        'lng': place['location']['longitude'],
        'address': place['formattedAddress'],
        'typeOfLocation': random.choice(typeOfLocation),
        'adsFormat': random.choice(adsFormat),
        'isPlanned': random.random() > 0.7,
        'image': '',
        'ward': '',
        'district': ''
    }

    for addr_component in place['addressComponents']:
        # Get the ward
        if 'administrative_area_level_3' in addr_component['types']:
            ward = addr_component['longText']
        else:
            print("[Google Maps API] Fail to find ward in ", place['formattedAddress'])
            ward = getWardFromAddress(place['formattedAddress'])
            
        # Get the district
        if 'administrative_area_level_2' in addr_component['types']:
            district = addr_component['longText']
        else:
            print("[Google Maps API] Fail to find district in ", place['formattedAddress'])
            district = getDistrictFromAddress(place['formattedAddress'])
    
    if (ward == '' or district == ''):
        return None

    output['ward'] = ward
    output['district'] = district

    return output

# %%
import csv

# Specify the file path
file_path = "dataMA.csv"

# Read the CSV data from the file
with open(file_path, "r", encoding='utf-8') as file:
    json_input = file.read().splitlines()

# %%
# Create an empty JSON array
json_output = []

# Iterate through the JSON array
for item in json_input:
    # Get the location
    location = getLocation(item)
    # Add the location to the JSON
    if location == None:
        print("Fail to get location of ", item)
        continue
    json_output.append(location)
# Out:
# {'formattedAddress': '231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '231', 'shortText': '231', 'types': ['subpremise'], 'languageCode': 'en'}, {'longText': '233', 'shortText': '233', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Lê Hồng Phong', 'shortText': 'Đ. Lê Hồng Phong', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7597268, 'longitude': 106.677128}, 'displayName': {'text': 'Công Ty CP xe khách Phương Trang', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  231, 233 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam', 'addressComponents': [{'longText': '280', 'shortText': '280', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '720000', 'shortText': '720000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.761383200000001, 'longitude': 106.68217109999999}, 'displayName': {'text': 'Ho Chi Minh City University of Education', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find district in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find district in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find district in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find district in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find ward in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# [Google Maps API] Fail to find district in  280 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh 720000, Vietnam
# {'formattedAddress': '227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '227', 'shortText': '227', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Nguyễn Văn Cừ', 'shortText': 'Đ. Nguyễn Văn Cừ', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7623158, 'longitude': 106.6826548}, 'displayName': {'text': 'Trung tâm Bồi đường Văn hóa ĐH KHTN', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '227', 'shortText': '227', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Nguyễn Văn Cừ', 'shortText': 'Đ. Nguyễn Văn Cừ', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.762835599999999, 'longitude': 106.6824824}, 'displayName': {'text': 'University of Science - VNUHCM', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  227 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '320/1', 'shortText': '320/1', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7623271, 'longitude': 106.67982409999999}, 'displayName': {'text': 'Lam Sơn Sports Complex', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  320/1 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam', 'addressComponents': [{'longText': '241', 'shortText': '241', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Nguyễn Văn Cừ', 'shortText': 'Đ. Nguyễn Văn Cừ', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '77000', 'shortText': '77000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.7647677, 'longitude': 106.6816667}, 'displayName': {'text': 'Nguyen Van Cu Bookstore', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find district in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find district in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find district in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find district in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find ward in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# [Google Maps API] Fail to find district in  241 Đ. Nguyễn Văn Cừ, Phường 4, Thành phố Hồ Chí Minh, 77000, Vietnam
# {'formattedAddress': '204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '204', 'shortText': '204', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.760588199999999, 'longitude': 106.67996250000002}, 'displayName': {'text': 'Apolo English', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  204 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '220', 'shortText': '220', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Lê Hồng Phong', 'shortText': 'Đ. Lê Hồng Phong', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.759951899999999, 'longitude': 106.67737419999999}, 'displayName': {'text': 'An Phú Express - Chuyển Phát Nhanh', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Lê Hồng Phong, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam', 'addressComponents': [{'longText': '210A', 'shortText': '210A', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '700000', 'shortText': '700000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.7607517, 'longitude': 106.67989639999999}, 'displayName': {'text': 'The IELTS Workshop Quận 5', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  210A Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh 700000, Vietnam
# {'formattedAddress': '292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '292a', 'shortText': '292a', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7602245, 'longitude': 106.68058719999999}, 'displayName': {'text': 'Mì Cay Sasin An Dương Vương', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  292a Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '290B', 'shortText': '290B', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7603565, 'longitude': 106.68061469999999}, 'displayName': {'text': 'Shinhan Bank, An Dong Branch', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290B Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam', 'addressComponents': [{'longText': '235', 'shortText': '235', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Nguyễn Văn Cừ', 'shortText': 'Đ. Nguyễn Văn Cừ', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '70000', 'shortText': '70000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.763846599999999, 'longitude': 106.6817617}, 'displayName': {'text': 'Le Hong Phong High School for The Gifted', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  235 Đ. Nguyễn Văn Cừ, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# {'formattedAddress': '5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '5A/2', 'shortText': '5A/2', 'types': ['premise'], 'languageCode': 'vi'}, {'longText': 'Đường Trần Phú', 'shortText': 'Đ. Trần Phú', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'St', 'shortText': 'St', 'types': ['neighborhood', 'political'], 'languageCode': 'vi'}, {'longText': 'Ward 4', 'shortText': 'Ward 4', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7643796, 'longitude': 106.68123489999999}, 'displayName': {'text': 'EX World - Business Center', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  5A/2, Đ. Trần Phú, St, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '131', 'shortText': '131', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Hùng Vương', 'shortText': 'Đ. Hùng Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.762384599999999, 'longitude': 106.6767723}, 'displayName': {'text': 'Công Ty Tnhh Một Thành Viên Cực Nam', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  131 Đ. Hùng Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam', 'addressComponents': [{'longText': '01', 'shortText': '01', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Vĩnh Viễn', 'shortText': 'Đ. Vĩnh Viễn', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 10', 'shortText': 'Quận 10', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '700000', 'shortText': '700000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.7651387, 'longitude': 106.67495629999999}, 'displayName': {'text': 'Giao Nước, Đổi Nước tại quận 10 - Công Ty TNHH DVTM Lê Đức', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  01 Đ. Vĩnh Viễn, Phường 2, Quận 10, Thành phố Hồ Chí Minh 700000, Vietnam
# {'formattedAddress': '9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '9', 'shortText': '9', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Phú', 'shortText': 'Đ. Trần Phú', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7638436, 'longitude': 106.6804217}, 'displayName': {'text': 'HEAD Minh Khang 1', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  9 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '269', 'shortText': '269', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7610025, 'longitude': 106.6795164}, 'displayName': {'text': 'Phụ Tùng Ô Tô Huy', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  269 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '196', 'shortText': '196', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7603436, 'longitude': 106.68016949999999}, 'displayName': {'text': 'Công Ty TNHH Tư Vấn Và Đầu Tư Hoàng Sơn', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  196 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam', 'addressComponents': [{'longText': '580', 'shortText': '580', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Cô Bắc', 'shortText': 'Đ. Cô Bắc', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 1', 'shortText': 'Quận 1', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '700000', 'shortText': '700000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.7660559, 'longitude': 106.69632159999999}, 'displayName': {'text': 'Nhà Thuốc FPT Long Châu', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find ward in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# [Google Maps API] Fail to find district in  580 Đ. Cô Bắc, Phường Cô Giang, Quận 1, Thành phố Hồ Chí Minh 700000, Vietnam
# {'formattedAddress': '76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '76', 'shortText': '76', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Cách Mạng Tháng 8', 'shortText': 'Đ. Cách Mạng Tháng 8', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 3', 'shortText': 'Quận 3', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7754944, 'longitude': 106.6863425}, 'displayName': {'text': 'Ngân Hàng Tmcp Ngoại Thương Việt Nam (Vietcombank) - Pgd Nguyễn Thị Minh Khai', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  76 Đ. Cách Mạng Tháng 8, Phường 4, Quận 3, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '240', 'shortText': '240', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.761249099999999, 'longitude': 106.6797611}, 'displayName': {'text': 'Công Ty Cp In Sách Giáo Khoa Tp. Hcm (Hcmtpc)', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  240 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '290', 'shortText': '290', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7606857, 'longitude': 106.68093739999999}, 'displayName': {'text': 'Khu Căn Hộ Cao Cấp EVERICH INFINITY', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  290 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '288A', 'shortText': '288A', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7605106, 'longitude': 106.6810903}, 'displayName': {'text': 'International Bank - VIB Ho Chi Minh City', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  288A Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '220', 'shortText': '220', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7609795, 'longitude': 106.67986}, 'displayName': {'text': 'Saigon Practical High School', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  220 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '889', 'shortText': '889', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Hưng Phú', 'shortText': 'Đ. Hưng Phú', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 8', 'shortText': 'Quận 8', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7452171, 'longitude': 106.6635422}, 'displayName': {'text': 'Cửa Hàng Giao Dịch Viettel', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  889 Đ. Hưng Phú, Phường 10, Quận 8, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam', 'addressComponents': [{'longText': '199', 'shortText': '199', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Phú', 'shortText': 'Đ. Trần Phú', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '70000', 'shortText': '70000', 'types': ['postal_code'], 'languageCode': 'en'}], 'location': {'latitude': 10.759044000000001, 'longitude': 106.67593529999999}, 'displayName': {'text': 'Trung Tâm Bảo Hành VietMap', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find ward in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# [Google Maps API] Fail to find district in  199 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh 70000, Vietnam
# {'formattedAddress': '195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '195', 'shortText': '195', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Phú', 'shortText': 'Đ. Trần Phú', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7591945, 'longitude': 106.6759458}, 'displayName': {'text': 'Gallery Hoang Khang', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  195 Đ. Trần Phú, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '326', 'shortText': '326', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường An Dương Vương', 'shortText': 'Đ. An Dương Vương', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7598924, 'longitude': 106.67948059999999}, 'displayName': {'text': 'Popeyes An Duong Vuong', 'languageCode': 'en'}}
# [Google Maps API] Fail to find ward in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  326 Đ. An Dương Vương, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# {'formattedAddress': '251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam', 'addressComponents': [{'longText': '251', 'shortText': '251', 'types': ['street_number'], 'languageCode': 'en'}, {'longText': 'Đường Trần Bình Trọng', 'shortText': 'Đ. Trần Bình Trọng', 'types': ['route'], 'languageCode': 'vi'}, {'longText': 'Quận 5', 'shortText': 'Quận 5', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'vi'}, {'longText': 'Thành phố Hồ Chí Minh', 'shortText': 'Thành phố Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'vi'}, {'longText': 'Vietnam', 'shortText': 'VN', 'types': ['country', 'political'], 'languageCode': 'en'}], 'location': {'latitude': 10.7605001, 'longitude': 106.67961299999999}, 'displayName': {'text': 'Trung tâm Kumon Trần Bình Trọng', 'languageCode': 'vi'}}
# [Google Maps API] Fail to find ward in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find ward in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam
# [Google Maps API] Fail to find district in  251 Đ. Trần Bình Trọng, Phường 4, Quận 5, Thành phố Hồ Chí Minh, Vietnam

# %%
# Write the JSON data to the file
output_path = "full3.json"
with open(output_path, "w", encoding='utf-8') as file:
    json.dump(json_output, file, ensure_ascii=False)
